# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter

# %%
df = pd.read_csv('responses.csv')

# %%
df
# Out:
#              Timestamp How old are you?  \
# 0   4/12/2022 16:37:08            23-27
# 1   4/12/2022 16:37:56            23-27
# 2   4/12/2022 16:40:07            23-27
# 3   4/12/2022 16:40:17            23-27
# 4   4/12/2022 16:42:54            23-27
# 5   4/12/2022 16:44:07            18-22
# 6   4/12/2022 16:44:55            23-27
# 7   4/12/2022 16:44:59            23-27
# 8   4/12/2022 16:49:19            18-22
# 9   4/12/2022 16:49:45            18-22
# 10  4/12/2022 16:51:25            18-22
# 11  4/12/2022 17:04:41            23-27
# 12  4/12/2022 17:27:18            23-27
# 13  4/12/2022 17:48:31            23-27
# 14  4/12/2022 18:13:01            23-27
# 15  4/12/2022 18:30:47            23-27
# 16  4/12/2022 18:50:34            23-27
# 17  4/12/2022 19:10:50            23-27
# 18  4/12/2022 20:17:46            23-27
# 19  4/12/2022 21:34:41            23-27
# 20  4/12/2022 21:39:17            23-27
# 21  4/12/2022 22:38:23            23-27
# 22  4/12/2022 23:03:02            23-27
# 23   4/13/2022 9:23:09            23-27
# 24  4/13/2022 14:19:03            23-27
# 25  4/13/2022 16:15:34            18-22
# 26  4/14/2022 12:06:38            18-22
# 27  4/21/2022 16:39:54            18-22
# 28  4/21/2022 16:56:06            23-27
# 29  4/21/2022 16:59:10            23-27
# 30  4/21/2022 17:22:33            23-27
# 31  4/21/2022 17:24:02            23-27
# 32  4/21/2022 18:49:57            23-27
# 33  4/21/2022 22:46:36            23-27
#
#    Do you often negotiate with traders over goods' prices  \
# 0                                                 Yes
# 1                                                 Yes
# 2                                                 Yes
# 3                                                 Yes
# 4                                                 Yes
# 5                                           Sometimes
# 6                                                 Yes
# 7                                                 Yes
# 8                                                 Yes
# 9                                           Sometimes
# 10                                                Yes
# 11                                                Yes
# 12                                          Sometimes
# 13                                          Sometimes
# 14                                                Yes
# 15                                                Yes
# 16                                                Yes
# 17                                                Yes
# 18                                                Yes
# 19                                                Yes
# 20                                          Sometimes
# 21                                                Yes
# 22                                                Yes
# 23                                          Sometimes
# 24                                          Sometimes
# 25                                                Yes
# 26                                                Yes
# 27                                          Sometimes
# 28                                          Sometimes
# 29                                                Yes
# 30                                                 No
# 31                                                Yes
# 32                                          Sometimes
# 33                                                Yes
#
#                      How do you know when to bargain? When to bargain  \
# 0                          Compare with prices online  Compare Prices
# 1                       When the price is ridiculous       High Price
# 2        if i know the price or price is unfavorable      Knows Price
# 3                       When the price seems too high      High Price
# 4   I negotiate first to see if there is a lower p...           Other
# 5   When l know the price \nDont have enough money...     Knows Price
# 6                                                 NaN             NaN
# 7   When the business setting doesn't have set pri...    No set Price
# 8   When other alternatives of what i want to get ...  Compare Prices
# 9   It's always part of the buying process except ...          Always
# 10  As longs as the prices aren't fixed like in su...    No set Price
# 11                     When the price charged is high      High Price
# 12     When the item doesn't deserve the stated price      High Price
# 13              When I sense an item being overpriced      High Price
# 14                                             Always          Always
# 15                         Yes, when I know the price     Knows Price
# 16                                When i want to save           Other
# 17               I have a price prior to negotiating      Knows Price
# 18                                 When over charged       High Price
# 19  When I’m not in the supermarket and the produc...    No set Price
# 20  When the product seems over priced for the val...      High Price
# 21  When I have an expected price in mind and the ...      High Price
# 22         When the price is higher than anticipated       High Price
# 23  According to product price and the type of the...           Other
# 24  When the price seems unfair compared to other ...      High Price
# 25         When I feel like the price is exaggerated       High Price
# 26         When I feel like I can get a better offer   Compare Prices
# 27                     When the price is exaggerated       High Price
# 28  If I feel like the price is  higher than I exp...      High Price
# 29  If maybe a friend has already told me the pric...     Knows Price
# 30           When the price is above what I budgeted       High Price
# 31                        I bargain for everything 😂😂          Always
# 32  When I'm not buying from a store or a place wi...    No set Price
# 33                              If the price is hiked      High Price
#
#    Do you need to see/know all the details of a product before you bargain for it?  \
# 0                                                 Yes
# 1                                                 Yes
# 2                                                 Yes
# 3                                                 Yes
# 4                                                  No
# 5                                                 Yes
# 6                                                  No
# 7                                               Maybe
# 8                                                 Yes
# 9                                                 Yes
# 10                                                 No
# 11                                              Maybe
# 12                                                Yes
# 13                                                Yes
# 14                                                Yes
# 15                                                Yes
# 16                                                Yes
# 17                                                Yes
# 18                                                Yes
# 19                                                 No
# 20                                                Yes
# 21                                              Maybe
# 22                                              Maybe
# 23                                                Yes
# 24                                                Yes
# 25                                                 No
# 26                                              Maybe
# 27                                                Yes
# 28                                                Yes
# 29                                              Maybe
# 30                                              Maybe
# 31                                                Yes
# 32                                                Yes
# 33                                                Yes
#
#    How do you determine the trader you choose to purchase from?  \
# 0              Price and visual inspection of product
# 1                                             Variety
# 2                   recent experience with the trader
# 3                                   Quality and price
# 4                The price range and product reviews.
# 5   A person well recommended \nIf its something c...
# 6                                                 NaN
# 7                    Cheapest price and good quality
# 8                           Quality of goods on offer
# 9                     If he/has what I am looking for
# 10                                            Referal
# 11                                By quality products
# 12                        The rating, recommendations
# 13                                          Reference
# 14     The one with the best quality and lowest price
# 15                                 By items they have
# 16                                        The nearest
# 17  Sometimes reputation, past experiences with ne...
# 18                                             Gender
# 19  Depending on the appearance, brand and date of...
# 20          survey shops, recommendations from people
# 21                                    Usually random
# 22                      Prices and quality of product
# 23                 According to his/her customer care
# 24                                  Their reputation.
# 25                                       Convenience
# 26                           References from friends
# 27     Quality, Referrals and ratings if online store
# 28                                   Proper marketing
# 29                               Its allll at random
# 30                       Reviews from his/her clients
# 31           How long they have been in the business
# 32                   Recommendations, amount of stock
# 33  Based on how well know the products are and th...
#
#    Choosing traders to buy from  \
# 0                 Price/Quality
# 1       Seller has Many Options
# 2                    Experience
# 3                 Price/Quality
# 4                 Price/Quality
# 5             Reviews/Referrals
# 6                           NaN
# 7                 Price/Quality
# 8                 Price/Quality
# 9                Nearest/Random
# 10            Reviews/Referrals
# 11                Price/Quality
# 12            Reviews/Referrals
# 13            Reviews/Referrals
# 14                Price/Quality
# 15               Nearest/Random
# 16               Nearest/Random
# 17            Reviews/Referrals
# 18                        Other
# 19                Price/Quality
# 20            Reviews/Referrals
# 21               Nearest/Random
# 22                Price/Quality
# 23                        Other
# 24            Reviews/Referrals
# 25               Nearest/Random
# 26            Reviews/Referrals
# 27                Price/Quality
# 28                        Other
# 29               Nearest/Random
# 30            Reviews/Referrals
# 31                        Other
# 32            Reviews/Referrals
# 33            Reviews/Referrals
#
#    How do you decide that the price settled on is the best price?  \
# 0                   Close or lower than online price
# 1       When I feel satisfied with the settled price
# 2                if it coincides with my expectations
# 3         By comparing with other services providers
# 4   When we no longer go any lower also when the i...
# 5   If we meet half way \nOr umm if he agrees with...
# 6                                                 NaN
# 7           When I feel like value for money is okay
# 8   on the 2nd or 3rd price proposed during bargai...
# 9   When you can no longer bargain with the seller...
# 10  Always half or 3/4 of the mentioned price by t...
# 11               By comparing with respect to quality
# 12  when the trader is serious and confident about...
# 13                               If it fits my budget
# 14                     According to the factory price
# 15                                                NaN
# 16                                If its in my budget
# 17  If it lies with in my budget and the value I a...
# 18                       After knowing the last price
# 19  By starting from a lower price and meeting the...
# 20                                 when I'm satisfied
# 21              Depends on the "look" of the product
# 22               When I'm comfortable with the price
# 23  Comparing it with the current trending price m...
# 24     When I compare it with other prices around me
# 25            When I feel like I am not being cheated
# 26              When I feel like I am willing to pay
# 27                         Based on previous purchase
# 28                  Depends on my Budget for the item
# 29                          When the trader looks sad
# 30                                                NaN
# 31                           If it's below my budget
# 32  If it's less than or not so much more than my ...
# 33  Comparing with other shops that offer the same...
#
#       Decide on best price Are you comfortable chatting with a bot?  \
# 0              Lower Price                                      Yes
# 1             Satisfaction                                    Maybe
# 2             Satisfaction                                       No
# 3   Comparison with others                                      Yes
# 4              Lower Price                                    Maybe
# 5               Know Price                                    Maybe
# 6                      NaN                                      Yes
# 7             Satisfaction                                      Yes
# 8              Lower Price                                      Yes
# 9                   Other                           I don't mind it
# 10             Lower Price                                    Maybe
# 11        Quality vs Price                                    Maybe
# 12                  Other                                       Yes
# 13            Satisfaction                                      Yes
# 14              Know Price                                    Maybe
# 15                     NaN                                    Maybe
# 16            Satisfaction                                      Yes
# 17        Quality vs Price                                    Maybe
# 18             Lower Price                                    Maybe
# 19             Lower Price                                    Maybe
# 20            Satisfaction                                      Yes
# 21        Quality vs Price                                    Maybe
# 22            Satisfaction                                      Yes
# 23  Comparison with Others                                    Maybe
# 24  Comparison with Others                                    Maybe
# 25            Satisfaction                                    Maybe
# 26            Satisfaction                                    Maybe
# 27  Comparison with Others                                    Maybe
# 28            Satisfaction                                    Maybe
# 29                   Other                                      Yes
# 30                     NaN                                       No
# 31             Lower Price                                       No
# 32             Lower Price                                      Yes
# 33  Comparison with others                                       No
#
#    What difficulties do you face as you bargain for a good?  \
# 0                                        Rigid seller
# 1                        Refusal to reduce the price
# 2                         ignorance of market prices
# 3            Unwillingness of the seller to negotiate
# 4   Not knowing the price range for an item before...
# 5   Language \nSometimes they are really charming ...
# 6                                                 NaN
# 7   Language barrier, high initial price from seller
# 8   Lack of bargaining leverage in regards to othe...
# 9   Some people are really rude so you end up not ...
# 10                                       Rude traders
# 11                        Having items of fixed price
# 12       Trader being vigorous, raising his/her voice
# 13  Sometimes it makes the transaction seem a bit ...
# 14                                   Language barrier
# 15      Not knowing the actual price or if it's legit
# 16                        Failure to agree on a price
# 17                  Sometimes, there’s no price prior
# 18                                    Time consuming
# 19                              Information asymmetry
# 20  want to save money but also want the trader to...
# 21  Lack of market information especially price of...
# 22  Language barrier and little information about ...
# 23       Knowledge about the exact price of the goods
# 24                                Lack of confidence.
# 25                              Low bargaining power
# 26                                      Time wastage
# 27                                                NaN
# 28                             Rude traders good Lord
# 29                                            Empathy
# 30                                                NaN
# 31                     Late replies from the traders
# 32                                      Tough sellers
# 33                                   Language barrier
#
#       Difficulties faced Are you willing to bargain over the phone?
# 0          Rigid Sellers                                        Yes
# 1          Rigid Sellers                                      Maybe
# 2        Price Ignorance                                         No
# 3          Rigid Sellers                                        Yes
# 4        Price Ignorance                                        Yes
# 5         Time Consuming                                         No
# 6                    NaN                                      Maybe
# 7       Language Barrier                                        Yes
# 8   Low Bargaining Power                                        Yes
# 9           Rude Traders                                      Maybe
# 10          Rude Traders                                        Yes
# 11         Rigid Sellers                                        Yes
# 12          Rude Traders                                        Yes
# 13        Time Consuming                                        Yes
# 14      Language Barrier                                        Yes
# 15       Price Ignorance                                      Maybe
# 16                 Other                                        Yes
# 17       Price Ignorance                                      Maybe
# 18        Time Consuming                                      Maybe
# 19       Price Ignorance                                        Yes
# 20                 Other                                         No
# 21       Price Ignorance                                        Yes
# 22      Language Barrier                                        Yes
# 23       Price Ignorance                                      Maybe
# 24  Low Bargaining Power                                        Yes
# 25  Low Bargaining Power                                        Yes
# 26        Time Consuming                                        Yes
# 27                   NaN                                      Maybe
# 28          Rude Traders                                        Yes
# 29                 Other                                      Maybe
# 30                   NaN                                        Yes
# 31                 Other                                        Yes
# 32         Rigid Sellers                                         No
# 33      Language Barrier                                        Yes

# %%
data = df['When to bargain']

data = data.dropna()

data = data.value_counts().sort_values()

plt.bar(x=data.index, height=data.values, color="orange", width=0.5)
 
plt.xticks(rotation=90)

plt.xlabel("No. Of Correspondents")

plt.ylabel("Response")

plt.title("How Respondents Choose When To Bargain")

plt.savefig('when_to_bargain.png',bbox_inches='tight')

# %%
data = df['Choosing traders to buy from']

data = data.dropna()

data = data.dropna()

data = data.value_counts().sort_values()

plt.bar(x=data.index, height=data.values, color="blue", width=0.5)
 
plt.xticks(rotation=90)

plt.xlabel("Responses")

plt.ylabel("No Of Correspondents")

plt.title("Linear graph")

plt.title("How Respondents Choose Where TO Buy From")

plt.savefig('where_to_buy_from.png',bbox_inches='tight')

# %%
data = df['Decide on best price']

data = data.dropna()

data = data.dropna()

data = data.value_counts().sort_values()

plt.bar(x=data.index, height=data.values, color="red", width=0.5)
 
plt.xticks(rotation=90)

plt.xlabel("Responses")

plt.ylabel("No Of Correspondents")

plt.title("How Respondents Decide On A Final Price")

plt.savefig('decide_on_the_best_price.png',bbox_inches='tight')

# %%
data = df['Difficulties faced']

data = data.dropna()

data = data.dropna()

data = data.value_counts().sort_values()

plt.bar(x=data.index, height=data.values, color="green", width=0.5)
 
plt.xticks(rotation=90)

plt.xlabel("Responses")

plt.ylabel("No Of Correspondents")

plt.title("Difficulties Faced By Correspondents During Bargaining")

plt.savefig('difficulties_faced.png',bbox_inches='tight')
